# %% [markdown]
# <a href="https://colab.research.google.com/github/rcgopi100/CNNPretrainedVGG16/blob/main/vgg16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import Numpy, Keras Image and VGG16 libraries
import numpy as np
from keras.preprocessing import image
from keras.applications import vgg16

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5175a174-5ce9-4176-9f48-13fd9d4056b3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5175a174-5ce9-4176-9f48-13fd9d4056b3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving flower.jpg to flower.jpg

# %%
model = vgg16.VGG16()
model
# Out:
# ...
# 553467904/553467096 [==============================] - 5s 0us/step

# %%
img = image.load_img('flower.jpg', target_size=(224,224))
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F4F9B7DC810>

# %%
#convert image to array
input_img = image.img_to_array(img)
input_img = np.expand_dims(input_img, axis=0)
input_img
# Out:
# array([[[[203., 208., 214.],
#          [203., 207., 218.],
#          [203., 207., 219.],
#          ...,
#          [153., 141.,  91.],
#          [147., 137.,  86.],
#          [143., 136.,  82.]],
#
#         [[203., 208., 214.],
#          [203., 207., 216.],
#          [203., 207., 218.],
#          ...,
#          [154., 142.,  94.],
#          [152., 140.,  90.],
#          [147., 140.,  86.]],
#
#         [[203., 208., 214.],
#          [203., 207., 216.],
#          [203., 207., 216.],
#          ...,
#          [156., 144.,  96.],
#          [155., 143.,  95.],
#          [148., 138.,  87.]],
#
#         ...,
#
#         [[ 38.,  39.,  31.],
#          [ 41.,  42.,  34.],
#          [ 45.,  46.,  38.],
#          ...,
#          [ 75.,  83.,  46.],
#          [ 63.,  71.,  30.],
#          [ 62.,  70.,  31.]],
#
#         [[ 39.,  40.,  32.],
#          [ 48.,  49.,  41.],
#          [ 53.,  54.,  46.],
#          ...,
#          [ 77.,  83.,  47.],
# ...

# %%
predict_img = model.predict(input_img)
predict_img
# Out:
# array([[3.05578737e-07, 4.26656479e-05, 2.26003564e-07, 2.30163678e-07,
#         8.09272706e-07, 4.42982673e-06, 5.13311943e-06, 5.18421984e-06,
#         2.78640618e-06, 1.12787745e-06, 6.81875417e-06, 8.82964159e-05,
#         8.58488420e-05, 3.54265321e-05, 1.27700495e-03, 3.72253562e-05,
#         6.28964044e-05, 5.11727354e-04, 3.98794291e-05, 2.37619970e-04,
#         8.58197382e-06, 6.49429421e-06, 3.92633820e-06, 3.72681757e-06,
#         7.70820552e-05, 2.04036382e-06, 8.60090859e-06, 7.88476791e-06,
#         2.73991782e-06, 9.53123072e-06, 3.31184992e-06, 8.39840868e-06,
#         7.82992447e-06, 1.82564872e-06, 3.09656343e-06, 5.46039519e-06,
#         3.94358758e-05, 2.23494226e-06, 1.03303764e-05, 3.10655219e-06,
#         7.71864052e-06, 1.90423657e-06, 1.15880794e-05, 2.88405699e-05,
#         1.06960601e-06, 2.36297979e-06, 2.66098778e-05, 2.12312934e-05,
#         3.34994468e-07, 7.19070556e-07, 1.00934267e-06, 5.09901020e-06,
# ...

# %%
top_five_predict = vgg16.decode_predictions(predict_img, top=5)
top_five_predict
# Out:
# ...
# 40960/35363 [==================================] - 0s 0us/step
# [[('n11939491', 'daisy', 0.3561179),
#   ('n02843684', 'birdhouse', 0.09260903),
#   ('n04522168', 'vase', 0.08440339),
#   ('n03991062', 'pot', 0.051201515),
#   ('n07730033', 'cardoon', 0.04113514)]]
